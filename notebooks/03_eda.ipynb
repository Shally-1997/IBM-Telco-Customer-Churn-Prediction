# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Target variable distribution

# %%
df["Churn"].value_counts(normalize=True)*100
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %% [markdown]
# As we can see 1 in every 4 customer leaves the company, making a Churn prediction a valuable business problem

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.set_style("whitegrid")
df = pd.read_csv("../data/telco_cleaned.csv")

# %% [markdown]
# ### Churn by Gender

# %%
plt.figure(figsize=(6,4))

sns.countplot(data = df, x = "Churn")
plt.title("Distribution of Churn")
plt.show()

# %% [markdown]
# 73% customers stayed while 27% churned.
# The dataset is moderately imbalanced.

# %%
plt.figure(figsize=(6,4))

sns.countplot(data= df, x="gender", hue="Churn")
plt.title("Gender vs Churn")
plt.show()

# %% [markdown]
# ### Churn by Senior Citizens

# %%
plt.figure(figsize=(6,4))

sns.countplot(data = df, x= "SeniorCitizen", hue="Churn")
plt.title("Senior Citizen vs Churn")
plt.show()

# %%
### Contract type vs Churn
plt.figure(figsize=(8,5))
sns.countplot(data = df, x="Contract", hue="Churn")
plt.title("Contract Type vs Churn")
plt.show()

# %%
### Internet Service vs Churn
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="InternetService", hue="Churn")
plt.title("Internet Service vs Churn")
plt.show()

# %%
### payment Method vs Churn
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="PaymentMethod", hue="Churn")
plt.xticks(rotation=20)
plt.title("Payment Method vs Churn")    
plt.show()

# %%
### Monthly Charges Distribution

plt.figure(figsize=(8,5))
sns.histplot(df["MonthlyCharges"], kde=True, bins=20)
plt.title("Monthly Charges Distribution")
plt.show()

# %% [markdown]
# ### monthly charges vs churn

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="Churn", y="MonthlyCharges")
plt.title("Monthly Charges vs Churn")
plt.show()

# %% [markdown]
# ### Tenure vs Churn

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Churn", y="tenure")
plt.title("Tenure vs Churn")
plt.show()

# %% [markdown]
# ### TotalCharges vs Churn

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Churn", y="TotalCharges")
plt.title("Total Charges vs Churn")
plt.show()
